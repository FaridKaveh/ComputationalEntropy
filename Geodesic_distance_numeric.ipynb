# %%
import mpmath
import numpy as np
import matplotlib.pyplot as plt
import os 
import pickle as pkl

os.chdir("/home/farid/Documents/git/ComputationalEntropy/Python/")

from geodesic_length import *
from log_partition import *

plt.rcParams['text.usetex'] = True

data_folder = "/home/farid/Documents/git/ComputationalEntropy/optimisation_data/"
mpmath.mp.dps = 200

# %%
geodesic_lengths_n10_deltaENeg3, _ = geodesic_length(-3, 
                                                          3, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)

geodesic_lengths_n10_deltaENeg6, _ = geodesic_length(-6, 
                                                          6, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)

geodesic_lengths_n10_deltaENeg9, _ = geodesic_length(-9, 
                                                          9, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)

geodesic_lengths_n10_deltaENeg12, _ = geodesic_length(-12, 
                                                          12, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)


#n=20

geodesic_lengths_n20_deltaENeg3, _ = geodesic_length(-3, 
                                                          3, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n20_deltaENeg6, _ = geodesic_length(-6, 
                                                          6, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n20_deltaENeg9, _ = geodesic_length(-9, 
                                                          9, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n20_deltaENeg12, _ = geodesic_length(-12, 
                                                          12, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)

#n=100
geodesic_lengths_n100_deltaENeg3, _ = geodesic_length(-3, 
                                                          3, 
                                                          100, 
                                                          maxdegree=12, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n100_deltaENeg6, _ = geodesic_length(-6, 
                                                          6, 
                                                          100, 
                                                          maxdegree=12, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n100_deltaENeg9, _ = geodesic_length(-9, 
                                                          9, 
                                                          100, 
                                                          maxdegree=12, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n100_deltaENeg12, _ = geodesic_length(-12, 
                                                          12, 
                                                          100, 
                                                          maxdegree=12, 
                                                          decimal_places=100, 
                                                          error=True)

#n=200
geodesic_lengths_n200_deltaENeg3, error = geodesic_length(-3, 
                                                          3, 
                                                          200, 
                                                          maxdegree=11, 
                                                          decimal_places=100, 
                                                          error=True)

# %%
#something is wrong with the v2 function. Need to fix it. Not a priority.
geodesic_lengths_n10_deltaENeg3, _ = geodesic_length_v2(-3, 
                                                          3, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)

geodesic_lengths_n10_deltaENeg6, _ = geodesic_length_v2(-6, 
                                                          6, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)

geodesic_lengths_n10_deltaENeg9, _ = geodesic_length_v2(-9, 
                                                          9, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)

geodesic_lengths_n10_deltaENeg12, _ = geodesic_length_v2(-12, 
                                                          12, 
                                                          10, 
                                                          maxdegree=8, 
                                                          decimal_places=50, 
                                                          error=True)


#n=20

geodesic_lengths_n20_deltaENeg3, _ = geodesic_length_v2(-3, 
                                                          3, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n20_deltaENeg6, _ = geodesic_length_v2(-6, 
                                                          6, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n20_deltaENeg9, _ = geodesic_length_v2(-9, 
                                                          9, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)

geodesic_lengths_n20_deltaENeg12, _ = geodesic_length_v2(-12, 
                                                          12, 
                                                          20, 
                                                          maxdegree=9, 
                                                          decimal_places=100, 
                                                          error=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 geodesic_lengths_n10_deltaENeg3, _ = geodesic_length_v2(-3,
#       2                                                           3,
#       3                                                           10,
#       4                                                           maxdegree=8,
#       5                                                           decimal_places=50,
#       6                                                           error=True)
#       8 geodesic_lengths_n10_deltaENeg6, _ = geodesic_length_v2(-6,
#       9                                                           6,
#      10                                                           10,
#      11                                                           maxdegree=8,
# ...

# %%
optimal_sum_n10_deltaENeg3 = np.load(data_folder+"optimalProtocolCost_n10_deltaE-3.0_m_min5_m_max100_step5.npy", allow_pickle=True)
optimal_sum_n10_deltaENeg6 = np.load(data_folder+"optimalProtocolCost_n10_deltaE-6.0_m_min5_m_max50_step5.npy", allow_pickle=True)
optimal_sum_n10_deltaENeg9 = np.load(data_folder+"optimalProtocolCost_n10_deltaE-9.0_m_min5_m_max50_step5.npy", allow_pickle=True)
optimal_sum_n10_deltaENeg12 = np.load(data_folder+"optimalProtocolCost_n10_deltaE-12.0_m_min5_m_max50_step5.npy", allow_pickle=True)


#N=20
optimal_sum_n20_deltaENeg3 = np.load(data_folder+"optimalProtocolCost_n20_deltaE-3.0_m_min5_m_max100_step5.npy", allow_pickle=True)
optimal_sum_n20_deltaENeg6 = np.load(data_folder+"optimalProtocolCost_n20_deltaE-6.0_m_min5_m_max50_step5.npy", allow_pickle=True)
optimal_sum_n20_deltaENeg9 = np.load(data_folder+"optimalProtocolCost_n20_deltaE-9.0_m_min5_m_max50_step5.npy", allow_pickle=True)
optimal_sum_n20_deltaENeg12 = np.load(data_folder+"optimalProtocolCost_n20_deltaE-12.0_m_min5_m_max50_step5.npy", allow_pickle=True)

#N=100
optimal_sum_n100_deltaENeg3 = np.load(data_folder+"optimalProtocolCost_n100_deltaE-3.0_m_min5_m_max100_step5.npy", allow_pickle=True)
#N=200
optimal_sum_n200_deltaENeg3 = np.load(
    data_folder+"optimalProtocolCost_fimHeuristic_n200_deltaE-3.0_m_min5_m_max100_step5.npy",
    allow_pickle=True)

# %%
optimal_cost_n10_deltaENeg3 = optimal_sum_n10_deltaENeg3 - 3*9
optimal_cost_n10_deltaENeg6 = optimal_sum_n10_deltaENeg6 - 6*9
optimal_cost_n10_deltaENeg9 = optimal_sum_n10_deltaENeg9 - 9*9
optimal_cost_n10_deltaENeg12 = optimal_sum_n10_deltaENeg12 - 12*9

optimal_cost_n20_deltaENeg3 = optimal_sum_n20_deltaENeg3 - 3*19
optimal_cost_n20_deltaENeg6 = optimal_sum_n20_deltaENeg6 - 6*19
optimal_cost_n20_deltaENeg9 = optimal_sum_n20_deltaENeg9 - 9*19
optimal_cost_n20_deltaENeg12 = optimal_sum_n20_deltaENeg12 - 12*19

optimal_cost_n100_deltaENeg3 = optimal_sum_n100_deltaENeg3 - 3*99

optimal_cost_n200_deltaENeg3 = optimal_sum_n200_deltaENeg3 - 3*199

# %%
#n=10
geodesic_bounds_n10_deltaENeg3 = np.asarray([geodesic_lengths_n10_deltaENeg3**2/(2*i) for i in range(5,101,5)])
geodesic_bounds_n10_deltaENeg6 = np.asarray([geodesic_lengths_n10_deltaENeg6**2/(2*i) for i in range(5,101,5)])
geodesic_bounds_n10_deltaENeg9 = np.asarray([geodesic_lengths_n10_deltaENeg9**2/(2*i) for i in range(5,101,5)])
geodesic_bounds_n10_deltaENeg12 = np.asarray([geodesic_lengths_n10_deltaENeg12**2/(2*i) for i in range(1,101,5)])

#n=20
geodesic_bounds_n20_deltaENeg3 = np.asarray([geodesic_lengths_n20_deltaENeg3**2/(2*i) for i in range(5,101,5)])
geodesic_bounds_n20_deltaENeg6 = np.asarray([geodesic_lengths_n20_deltaENeg6**2/(2*i) for i in range(5,101,5)])
geodesic_bounds_n20_deltaENeg9 = np.asarray([geodesic_lengths_n20_deltaENeg9**2/(2*i) for i in range(5,101, 5)])
geodesic_bounds_n20_deltaENeg12 = np.asarray([geodesic_lengths_n20_deltaENeg12**2/(2*i) for i in range(5,101, 5)])

#n=100
geodesic_bounds_n100_deltaENeg3 = np.asarray([geodesic_lengths_n100_deltaENeg3**2/(2*i) for i in range(5,101,5)])
geodesic_bounds_n100_deltaENeg6 = np.asarray([geodesic_lengths_n100_deltaENeg6**2/(2*i) for i in range(5,101,5)])
geodesic_bounds_n100_deltaENeg9 = np.asarray([geodesic_lengths_n100_deltaENeg9**2/(2*i) for i in range(5,101, 5)])
geodesic_bounds_n100_deltaENeg12 = np.asarray([geodesic_lengths_n100_deltaENeg12**2/(2*i) for i in range(5,101, 5)])

#n=200
geodesic_bounds_n200_deltaENeg3 = np.asarray([geodesic_lengths_n200_deltaENeg3**2/(2*i) for i in range(5,201,5)])

# %%
# optimal_cost_n10_deltaENeg3_m50_m100= np.load(
#     data_folder+"optimalProtocolCost_n10_deltaE-3.0_m_min55_m_max100_step5.npy",
#     allow_pickle=True)

# optimal_cost_n10_deltaENeg3_m50_m100 = optimal_cost_n10_deltaENeg3_m50_m100 - 3*9

# optimal_cost_n20_deltaENeg3_m50_m100= np.load(
#     data_folder+"optimalProtocolCost_n20_deltaE-3.0_m_min55_m_max100_step5.npy",
#     allow_pickle=True)

# optimal_cost_n20_deltaENeg3_m50_m100 = optimal_cost_n20_deltaENeg3_m50_m100 - 3*19

# %%
# optimal_cost_n10_deltaENeg3 = np.concatenate((optimal_cost_n10_deltaENeg3, optimal_cost_n10_deltaENeg3_m50_m100))
# optimal_cost_n10_deltaENeg3 = optimal_cost_n10_deltaENeg3[:20]

# %%
# optimal_cost_n20_deltaENeg3 = np.concatenate((optimal_cost_n20_deltaENeg3, optimal_cost_n20_deltaENeg3_m50_m100))
# optimal_cost_n20_deltaENeg3 = optimal_cost_n20_deltaENeg3[:20]

# %%
step_num_points = [i for i in range(5,101,5)]
fig, ax = plt.subplots()

ax.scatter(step_num_points, optimal_cost_n10_deltaENeg3, color='blue', label='Numerical', alpha=0.7)
ax.scatter(step_num_points, geodesic_bounds_n10_deltaENeg3, color='red',  label='Geodesic', alpha=0.6, marker='^')

ax.set_xlabel('Number of Steps')
ax.set_ylabel('Operational Entropy Cost')
ax.legend()
ax.set_title('Number of States N = 10')

plt.tight_layout()
plt.show()

# %%
step_num_points = [i for i in range(5,101,5)]
fig, ax = plt.subplots()

ax.scatter(step_num_points, optimal_cost_n20_deltaENeg3, color='blue', label='Numerical', alpha=0.7)
ax.scatter(step_num_points, geodesic_bounds_n20_deltaENeg3,  label='Geodesic', alpha=1, marker='^', facecolors='none', edgecolors='red',
          s=100)
ax.scatter(step_num_points, t2_lemma_cost_n20, label='T2 bound', alpha=1, marker='*', facecolors='none', edgecolors='green',
          s=100)

ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('Number of Steps, $K$')
ax.set_ylabel('Operational Entropy Cost')
ax.legend()
ax.set_title('Number of State, $N=20$')

plt.tight_layout()
plt.show()

# %%
step_num_points = [i for i in range(5,101,5)]
fig, ax = plt.subplots()

ax.scatter(step_num_points, optimal_cost_n100_deltaENeg3, color='blue', label='Numerical', alpha=0.7)
ax.scatter(step_num_points, geodesic_bounds_n100_deltaENeg3, color='red',  label='Geodesic', alpha=0.6, marker='^')

ax.set_xlabel('Number of Steps')
ax.set_ylabel('Operational Entropy Cost')
ax.legend()
ax.set_title('Number of State, N=100')
ax.set_ylim([0,11])

plt.tight_layout()
plt.show()

# %%
step_num_points = [i for i in range(5,51,5)]
fig, ax = plt.subplots()

ax.scatter(step_num_points, optimal_cost_n10_deltaENeg3[:10], color='red', label='delta = E-3', alpha=0.7)
ax.scatter(step_num_points, optimal_cost_n10_deltaENeg6, color='green',  label='delta = E-6', alpha=0.7, marker='^')
ax.scatter(step_num_points, optimal_cost_n10_deltaENeg9, color='brown',  label='delta = E-9', alpha=0.7, marker='s')
ax.scatter(step_num_points, optimal_cost_n10_deltaENeg12, color='blue',  label='delta = E-12', alpha=0.9, marker='*')


ax.set_xlabel('Number of Steps')
ax.set_ylabel('Optimal Operational Entropy Cost')
ax.legend()
ax.set_title('Number of State, N=10')


plt.tight_layout()
plt.show()

# %%
def phi(x: float, n: int) -> float:
    if x == 1:
        return (n - 1) / 2
    else:
        nom = x - n * (x**n) + (n - 1) * (x ** (n + 1))
        denom = (1 - x) * (1 - x**n)

        return nom / denom

def varphi(x, n, delta):
    return phi(1 / delta * mp.exp(-x), n)

# %%
optimal_protocol_n10_deltaENeg3 = np.load(data_folder+"optimalProtocol_n10_deltaE-3.0_m_min5_m_max100_step5.npy", allow_pickle=True)
optimal_protocol_n20_deltaENeg3 = np.load(data_folder+"optimalProtocol_n20_deltaE-3.0_m_min5_m_max100_step5.npy", allow_pickle=True)
optimal_protocol_n100_deltaENeg3 = np.load(data_folder+"optimalProtocol_n100_deltaE-3.0_m_min5_m_max100_step5.npy", allow_pickle=True)
optimal_protocol_n200_deltaENeg3 = np.load(
    data_folder+"optimalProtocol_fimHeuristic_n200_deltaE-3.0_m_min5_m_max100_step5.npy",
    allow_pickle=True
)

# %%
optimal_protocol_parameters_n10_deltaENeg3 = []

for i, protocol in enumerate(optimal_protocol_n10_deltaENeg3): 
    
    param_values = np.zeros(len(protocol) + 1)
    
    for i in range(len(protocol)):
        param_values[i+1] = param_values[i] + protocol[i]
        

    param_values = param_values - 3
    optimal_protocol_parameters_n10_deltaENeg3.append(param_values)

# %%
optimal_protocol_parameters_n20_deltaENeg3 = []

for i, protocol in enumerate(optimal_protocol_n20_deltaENeg3): 
    
    param_values = np.zeros(len(protocol) + 1)
    
    for i in range(len(protocol)):
        param_values[i+1] = param_values[i] + protocol[i]
        

    param_values = param_values - 3
    optimal_protocol_parameters_n20_deltaENeg3.append(param_values)

# %%
optimal_protocol_parameters_n100_deltaENeg3 = []

for i, protocol in enumerate(optimal_protocol_n100_deltaENeg3): 
    
    param_values = np.zeros(len(protocol) + 1)
    
    for i in range(len(protocol)):
        param_values[i+1] = param_values[i] + protocol[i]
        

    param_values = param_values - 3
    optimal_protocol_parameters_n100_deltaENeg3.append(param_values)

# %%
optimal_protocol_parameters_n100_deltaENeg3[1]
# Out:
# array([-3.        , -0.38459036, -0.07316506, -0.01221564,  0.02194314,
#         0.06237299,  0.13480838,  0.28796864,  0.61633002,  1.33103281,
#         3.        ])

# %%
k = 1
print(mth_order_perturbation_sum(10, 2, optimal_protocol_parameters_n10_deltaENeg3[1]) )
print(mth_order_perturbation_sum(10, 3, optimal_protocol_parameters_n10_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 4, optimal_protocol_parameters_n10_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 5, optimal_protocol_parameters_n10_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 6, optimal_protocol_parameters_n10_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 7, optimal_protocol_parameters_n10_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 8, optimal_protocol_parameters_n10_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 9, optimal_protocol_parameters_n10_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 10, optimal_protocol_parameters_n10_deltaENeg3[k]) )

print(total_entropy_mth_order(10, 7, optimal_protocol_parameters_n10_deltaENeg3[k]))
# Out:
# 1.552518578470946846492269181617901265447355694864872783646628465192467363283570952406455150797250884
# -0.1599596600384923724004369189281513290409033189546364041369339421883653664330402988013828982658358874
# 0.1855857053493971951272777970691106753380488467493250073463551762378658911209363800217681866360954787
# -0.03405627798486658381100048070621882137723437481876209636529659485677186263501049525907992995377566113
# 0.04055586743240811803620786132303760767186398940671700228422807396669159127990549753830437450284458879
# -0.009968662034633036651819169816802908540020963237334738802570268360363862173686196516950360425427957535
# 0.01091289759140925456069264810019512238157488335880725076202615142091850855232143916734220744374465978
# -0.003095161613621127578896590361427775595552455364269475972493440695823988289060438310447270505051955322
# 0.00311184445013056866055497212836395839895431901247472507712197164757758098408663405265218588338636722
# ...

# %%
k = 2
print(mth_order_perturbation_sum(20, 2, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 3, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 4, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 5, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 6, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 7, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 8, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 9, optimal_protocol_parameters_n20_deltaENeg3[k]) )
print(mth_order_perturbation_sum(20, 10, optimal_protocol_parameters_n20_deltaENeg3[k]) )

print(total_entropy_mth_order(20, 7, optimal_protocol_parameters_n20_deltaENeg3[k]))
# Out:
# 1.629193701251685952248673528777704344424939445229011467735201184322061300071487590759054046434861953
# -0.1325708430081957146969813452671943624901135642530480362356644340982224218288452971790193906426479186
# 0.1473624207479722590302767108766960886412628779200197649347871413028524449510822051622211240065181975
# -0.0215700685175693488754839381359508549225377343247626914614018550936139383521614049031114417542599073
# 0.02332565617693424922320075914070036527790498603633780973181286246623734669805363106811876369550204149
# -0.004713192722272247840698332559947740857228525390816300263158223913247069769662836246351695182541591911
# 0.004642689485437019015536370756858051344046568095312290014413244926698299984529053913787806212726717865
# -0.001156974934925138765617449009176207005962541376237930244435750368116188699222598411889369017126849969
# 0.001062364682471704514416656281820159370221534609512895254630519361149345149954559687677429455815126532
# ...

# %%
k = 3
print(mth_order_perturbation_sum(10, 2, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 3, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 4, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 5, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 6, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 7, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 8, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 9, optimal_protocol_parameters_n100_deltaENeg3[k]) )
print(mth_order_perturbation_sum(10, 10, optimal_protocol_parameters_n100_deltaENeg3[k]) )

print(total_entropy_mth_order(10, 7, optimal_protocol_parameters_n100_deltaENeg3[k]))
# Out:
# 1.120917519138087738086102458951950280700665448287800375638554615810041429768462362373799906203278734025676708025926882003065369872253746600931339539765385925446308296559744457065869116398938949587091
# -0.12210904765108122708262133563469400668425444314496783432045248968132511558610556706766527697708741052785241566780752679605152782487625475667521561285139485937178367075831486741118801980468838435143011
# 0.14274527314042833404721356745834215899361375663092798014110267441674866749450679058512229655288192679980955096051563590657637745708869822102592919069744635213143277767870667703618340383698897650914538
# -0.021431835098594861741869849929095607198847192324488255500023763403049834054173352895058949716048186065096326377791084667444096543116007646695294556964748117860143378523414129529393389877774879526289528
# ...

# %%
t2_lemma_bounds_n20 = np.asarray([t2_lemma_bound(20, protocol) for protocol in optimal_protocol_parameters_n20_deltaENeg3])
t2_lemma_bounds_n10 = np.asarray([t2_lemma_bound(10, protocol) for protocol in optimal_protocol_parameters_n10_deltaENeg3])
t2_lemma_bounds_n100 = np.asarray([t2_lemma_bound(100, protocol) for protocol in optimal_protocol_parameters_n100_deltaENeg3])

# %%
step_num_points = np.asarray([i for i in range(5,101,5)])
straight_line = 2*geodesic_lengths_n20_deltaENeg3/(step_num_points**(2))
fig, ax = plt.subplots()

ax.scatter(step_num_points, straight_line, color='blue', marker='^', alpha=1, label='y=2/x^2')
ax.scatter(step_num_points, geodesic_lengths_n20_deltaENeg3-t2_lemma_bounds_n20, color='red', label='delta = E-3', alpha=1)
ax.set_xscale('log')
ax.set_yscale('log')


ax.set_xlabel('Number of Steps')
ax.set_ylabel('bound difference')
ax.legend()
ax.set_title('Number of State, N=20')


plt.tight_layout()
plt.show()

# %%
step_num_points = np.asarray([i for i in range(5,101,5)])
straight_line = geodesic_lengths_n20_deltaENeg3**2/(step_num_points**(3))
# straight_line = geodesic_lengths_n20_deltaENeg3**2/(step_num_points**(14/5))
fig, ax = plt.subplots(tight_layout=True)
ax.scatter(step_num_points, geodesic_bounds_n20_deltaENeg3-optimal_cost_n20_deltaENeg3, color='blue', marker='*', alpha=1, 
           label=r'$\Gamma_K$', s=100)
# ax.scatter(step_num_points, geodesic_bounds_n20_deltaENeg3, color='red', label='geodesic_bound', alpha=1)
ax.scatter(step_num_points, straight_line, color='green', label=r"$y=\mathcal{L}_N^2/K^3$", alpha=0.5, s=100)
# ax.scatter(step_num_points, straight_line_2, color='red', label=r"$y=\mathcal{L}_N^2/K^{14/5}$", alpha=0.5, s=100)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Number of Steps, $K$', fontsize=24)
# ax.set_ylabel('bound difference')
ax.legend(fontsize=24)
ax.set_title('Number of States, $N=20$', fontsize=24)
ax.tick_params(axis='both', labelsize=24)
plt.tight_layout()
plt.show()

# %%
step_num_points = np.asarray([i for i in range(5,101,5)])
straight_line = geodesic_lengths_n10_deltaENeg3**2/(step_num_points**(3))
straight_line_2 = geodesic_lengths_n10_deltaENeg3**2/(step_num_points**(14/5))
fig, ax = plt.subplots(tight_layout=True)

ax.scatter(step_num_points, geodesic_bounds_n10_deltaENeg3-optimal_cost_n10_deltaENeg3, color='blue', marker='*', alpha=1, 
           label=r'$\Gamma_K$', s=100)
# ax.scatter(step_num_points, geodesic_bounds_n20_deltaENeg3, color='red', label='geodesic_bound', alpha=1)
ax.scatter(step_num_points, straight_line, color='green', label=r"$y=\mathcal{L}_N^2/K^3$", alpha=0.5, s=100)
ax.scatter(step_num_points, straight_line_2, color='red', label=r"$y=\mathcal{L}_N^2/K^{14/5}$", alpha=0.5,s=100)
ax.set_xscale('log')
ax.set_yscale('log')


ax.set_xlabel('Number of Steps, $K$',fontsize=24)
# ax.set_ylabel('bound difference')
ax.legend(fontsize=24)
ax.set_title('Number of States, $N=10$', fontsize=24)
ax.tick_params(axis='both', labelsize=24)


plt.tight_layout()
plt.show()

# %%
step_num_points = np.asarray([i for i in range(5,101,5)])
straight_line = geodesic_lengths_n100_deltaENeg3**2/(step_num_points**(3))
straight_line_2 = geodesic_lengths_n100_deltaENeg3**2/(step_num_points**(14/5))
fig, ax = plt.subplots(tight_layout=True)

ax.scatter(step_num_points, geodesic_bounds_n100_deltaENeg3-optimal_cost_n100_deltaENeg3, color='blue', marker='*', alpha=1,
           label=r'$\Gamma_K$', s=100)
# ax.scatter(step_num_points, geodesic_bounds_n20_deltaENeg3, color='red', label='geodesic_bound', alpha=1)
ax.scatter(step_num_points, straight_line, color='green', label=r"$y=\mathcal{L}_N^2/K^3$", alpha=0.5,s=100)
ax.scatter(step_num_points, straight_line_2, color='red', label=r"$y=\mathcal{L}_N^2/K^{14/5}$", alpha=0.5,s=100)
ax.set_xscale('log')
ax.set_yscale('log')


ax.set_xlabel('Number of Steps, $K$', fontsize=24)
# ax.set_ylabel('bound difference')
ax.legend(fontsize=24)
ax.set_title('Number of States, $N=100$', fontsize=24)
ax.tick_params(axis='both', labelsize=24)


plt.tight_layout()
plt.show()

# %%
t2_lemma_cost_n20 = np.asarray([bound**2/(2*5*(i+1)) for i, bound in enumerate(t2_lemma_bounds_n20)])

# %%
step_num_points = np.asarray([i for i in range(5,201,5)])
straight_line = np.asarray(geodesic_lengths_n200_deltaENeg3**2/(step_num_points**(3)), dtype=float)
straight_line_2 = np.asarray(geodesic_lengths_n200_deltaENeg3**2/(step_num_points**(20/7)), dtype=float)
fig, ax = plt.subplots(tight_layout=True)

ax.scatter(step_num_points, geodesic_bounds_n200_deltaENeg3-optimal_cost_n200_mmax200, color='blue', marker='*', alpha=1,
           label=r'$\Gamma_K$', s=50)
# ax.scatter(step_num_points, geodesic_bounds_n20_deltaENeg3, color='red', label='geodesic_bound', alpha=1)
ax.scatter(step_num_points, straight_line, color='green', label=r"$y=\mathcal{L}_N^2/K^3$", alpha=0.5,s=50)
# ax.scatter(step_num_points, straight_line_2, color='red', label=r"", alpha=0.5,s=50)
ax.set_xscale('log')
ax.set_yscale('log')

# ax.set_xlim((10,100))
ax.set_xlabel('Number of Steps, $K$', fontsize=24)
# ax.set_ylabel('bound difference')
ax.legend(fontsize=24)
ax.set_title('Number of States, $N=200$', fontsize=24)
ax.tick_params(axis='both', labelsize=24)


plt.tight_layout()
plt.show()

# %%
step_num_points = np.asarray([i for i in range(5,201,5)])
straight_line = np.asarray(geodesic_lengths_n200_deltaENeg3**2/(step_num_points**(3)), dtype=float)
straight_line_2 = np.asarray(geodesic_lengths_n200_deltaENeg3**2/(step_num_points**(20/7)), dtype=float)
fig, ax = plt.subplots(tight_layout=True)

bound_error = geodesic_bounds_n200_deltaENeg3-optimal_cost_n200_mmax200
ax.scatter(step_num_points, straight_line/bound_error, color='blue', marker='*', alpha=1,
           label=r'$\mathcal{L}_N^2/K^3$', s=50)
# ax.scatter(step_num_points, geodesic_bounds_n20_deltaENeg3, color='red', label='geodesic_bound', alpha=1)
# ax.scatter(step_num_points, straight_line, color='green', label=r"$y=\mathcal{L}_N^2/K^3$", alpha=0.5,s=50)
ax.scatter(step_num_points, straight_line_2/bound_error, color='red', label=r'$\mathcal{L}_N^2/K^{20/7}$', alpha=0.5,s=50)
# ax.set_xscale('log')
# ax.set_yscale('log')

ax.scatter(step_num_points, step_num_points**(1/7)/2, color='green', label=r'', alpha=0.5,s=50)
ax.set_xlabel('Number of Steps, $K$', fontsize=24)
# ax.set_ylabel('bound difference')
ax.legend(fontsize=24)
ax.set_title('Number of States, $N=200$', fontsize=24)
ax.tick_params(axis='both', labelsize=24)


plt.tight_layout()
plt.show()

# %%
with open(data_folder+"optimisation_N200_mmin_105_mmax_200_step5_deltaE-3.pkl", "rb") as f:
    res = pkl.load(f)

# %%
_optimal_cost_arrs_n200 = np.asarray([_out[2] for _out in res])
_optimal_cost_arrs_n200 = _optimal_cost_arrs_n200 - 199*3
optimal_cost_n200_mmax200 = list(optimal_cost_n200_deltaENeg3) + list(_optimal_cost_arrs_n200)

# %%
optimal_cost_n200_mmax200
# Out:
# [11.954037571529966,
#  6.553074696035878,
#  4.454564904740209,
#  3.364161991024048,
#  2.7001836525212184,
#  2.2542416547322546,
#  1.9343509966870442,
#  1.693786871873499,
#  1.5063430870818593,
#  1.356197173465489,
#  1.233236292067545,
#  1.1306971921897002,
#  1.0438865132496176,
#  0.9694457410529367,
#  0.904908434553704,
#  0.8484226457464956,
#  0.7985708576069328,
#  0.7542497134002133,
#  0.714587584566857,
#  0.6788867922706459,
#  0.6465822918988806,
#  0.6172115908151454,
#  0.5903925018997143,
#  0.565806442500616,
#  0.5431857325557985,
#  0.5223038242877465,
#  0.502967690734863,
#  0.48501185409043046,
#  0.46829363553069925,
#  0.4526893649065187,
#  0.438091312985307,
#  0.4244052123727897,
#  0.41154819964765466,
#  0.39944716604691166,
#  0.38803734586656446,
#  0.3772611709052853,
#  0.3670672860854438,
#  0.35740974149678095,
#  0.34824730025854933,
#  0.3395428425042155]
